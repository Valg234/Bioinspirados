# %%
import pandas as pd
import numpy as np
from math import radians, sin, cos, sqrt, atan2
import folium
import random
import os
import json
import warnings
import time
import os
import csv
import time
import requests

warnings.filterwarnings("ignore")


path_de_redes = 'redes'
path_de_resultados = 'resultados'

os.makedirs(path_de_redes, exist_ok=True)
os.makedirs(path_de_resultados, exist_ok=True)

# %% [markdown]
# ## Coordenadas geograficas

# %%
import os
import csv
import time
import requests
import re  # <- añadido

# ==== CONFIGURA AQUÍ ====
INPUT_DIR   = 'Instancias_Equipo4'  # carpeta de entrada
OUTPUT_DIR  = 'redes'               # carpeta de salida
API_KEY     = "apikey"         # o usa variable de entorno GOOGLE_MAPS_API_KEY
PAUSA_SEG   = 0.1                   # pausa corta entre llamadas
PAIS        = "México"
IDIOMA      = "es"
USAR_DEBUG  = True  # si True, agrega columnas geo_status y direccion_consultada
# ========================

def limpiar(x):
    return (str(x).strip()) if x is not None else ""

def construir_direccion(row):
    """
    Crea una dirección tipo:
    "calle num, colonia, C.P., Ciudad, País"
    """
    calle = limpiar(row.get("calle"))
    num   = limpiar(row.get("No.Casa"))
    if calle and num:
        calle = f"{calle} {num}"

    partes = [
        calle or "",
        limpiar(row.get("colonia")),
        limpiar(row.get("C.P.")),
        limpiar(row.get("Ciudad")),
        PAIS
    ]
    return ", ".join([p for p in partes if p])

def geocodificar(direccion, api_key, row=None):
    """
    Llama a Geocoding API con sesgo a MX y components (CP y Ciudad).
    Hace 1 reintento simple si NO hay resultados intentando sin número exterior.
    """
    url = "https://maps.googleapis.com/maps/api/geocode/json"

    # components (mejora precisión en MX)
    cp = limpiar((row or {}).get("C.P."))
    ciudad = limpiar((row or {}).get("Ciudad"))
    comps = ["country:MX"]
    if cp:
        comps.append(f"postal_code:{cp}")
    if ciudad:
        comps.append(f"locality:{ciudad}")

    params_base = {
        "key": api_key,
        "region": "mx",
        "language": IDIOMA,
        "components": "|".join(comps)
    }

    # 1) intento con la dirección completa
    params = dict(params_base)
    params["address"] = direccion
    lat, lon, status = _hit_geocode(url, params)
    if status == "OK":
        return lat, lon, status

    # 2) fallback: si no hubo resultados, intenta sin número exterior
    if status in ("ZERO_RESULTS", "NOT_FOUND", "INVALID_REQUEST"):
        direccion_sin_num = _eliminar_numero(direccion)
        if direccion_sin_num != direccion:
            params2 = dict(params_base)
            params2["address"] = direccion_sin_num
            lat2, lon2, status2 = _hit_geocode(url, params2)
            if status2 == "OK":
                return lat2, lon2, status2

    return "", "", status

def _hit_geocode(url, params):
    try:
        r = requests.get(url, params=params, timeout=20)
        r.raise_for_status()
        data = r.json()
        status = data.get("status", "UNKNOWN_ERROR")
        if status == "OK" and data.get("results"):
            loc = data["results"][0]["geometry"]["location"]
            return loc.get("lat"), loc.get("lng"), "OK"
        return "", "", status
    except requests.RequestException as e:
        return "", "", f"ERROR_HTTP: {e}"

def _eliminar_numero(direccion):
    """
    Quita un posible número exterior después del nombre de la calle (heurística simple).
    Ej: "Av. Patria 1234, ..." -> "Av. Patria, ..."
    """
    if "," in direccion:
        primera, resto = direccion.split(",", 1)
    else:
        primera, resto = direccion, ""

    trozos = primera.split()
    if len(trozos) >= 2 and any(ch.isdigit() for ch in trozos[-1]):
        # elimina el último token si parece número
        trozos = trozos[:-1]
    primera_sin = " ".join(trozos)

    if resto.strip():
        return f"{primera_sin}, {resto.strip()}"
    return primera_sin

def procesar_archivo(ruta_entrada, ruta_salida):
    with open(ruta_entrada, "r", encoding="utf-8-sig", newline="") as f_in:
        reader = csv.DictReader(f_in)
        requeridos = {"colonia", "calle", "No.Casa", "C.P.", "Ciudad"}
        faltantes = [h for h in requeridos if h not in reader.fieldnames]
        if faltantes:
            raise RuntimeError(f"Faltan columnas en el CSV: {faltantes}. Encabezados: {reader.fieldnames}")

        fieldnames = reader.fieldnames + ["lat", "lon"]
        if USAR_DEBUG:
            fieldnames += ["geo_status", "direccion_consultada"]

        with open(ruta_salida, "w", encoding="utf-8", newline="") as f_out:
            writer = csv.DictWriter(f_out, fieldnames=fieldnames)
            writer.writeheader()

            cache = {}
            for row in reader:
                direccion = construir_direccion(row)

                if direccion in cache:
                    lat, lon, status = cache[direccion]
                else:
                    lat, lon, status = geocodificar(direccion, API_KEY, row)
                    cache[direccion] = (lat, lon, status)
                    time.sleep(PAUSA_SEG)

                out_row = dict(row)
                out_row["lat"] = lat
                out_row["lon"] = lon
                if USAR_DEBUG:
                    out_row["geo_status"] = status
                    out_row["direccion_consultada"] = direccion

                writer.writerow(out_row)

def main():
    if not API_KEY or API_KEY in ("TU_API_KEY_AQUI", "tu api aqui"):
        raise RuntimeError("Falta API_KEY. Exporta GOOGLE_MAPS_API_KEY o edítala en el script.")

    os.makedirs(OUTPUT_DIR, exist_ok=True)

    # Recorre todos los CSV de la carpeta de instancias
    archivos = [f for f in os.listdir(INPUT_DIR) if f.lower().endswith(".csv")]
    if not archivos:
        print(f"No se encontraron CSV en: {INPUT_DIR}")
        return

    for fname in sorted(archivos):
        ruta_entrada = os.path.join(INPUT_DIR, fname)

        # TSP_E4_<TAM>_<INST>.csv  ->  <INST>_<TAM>.csv
        m = re.match(r'^TSP_E4_(\d+)_(\d+)\.csv$', fname, re.IGNORECASE)
        if m:
            tam, inst = m.group(1), m.group(2)
            nombre_salida = f"{inst}_{tam}.csv"
        else:
            # respaldo por si el patrón no coincide
            base = os.path.splitext(fname)[0]
            nombre_salida = f"{base}.out.csv"

        ruta_salida = os.path.join(OUTPUT_DIR, nombre_salida)

        procesar_archivo(ruta_entrada, ruta_salida)
        print(f"Listo: {fname} -> {nombre_salida}")

if __name__ == "__main__":
    main()
# Out:
# Listo: TSP_E4_100_1.csv -> 1_100.csv
# Listo: TSP_E4_100_10.csv -> 10_100.csv
# Listo: TSP_E4_100_2.csv -> 2_100.csv
# Listo: TSP_E4_100_3.csv -> 3_100.csv
# Listo: TSP_E4_100_4.csv -> 4_100.csv
# Listo: TSP_E4_100_5.csv -> 5_100.csv
# Listo: TSP_E4_100_6.csv -> 6_100.csv
# Listo: TSP_E4_100_7.csv -> 7_100.csv
# Listo: TSP_E4_100_8.csv -> 8_100.csv
# Listo: TSP_E4_100_9.csv -> 9_100.csv
# Listo: TSP_E4_150_1.csv -> 1_150.csv
# Listo: TSP_E4_150_10.csv -> 10_150.csv
# Listo: TSP_E4_150_2.csv -> 2_150.csv
# Listo: TSP_E4_150_3.csv -> 3_150.csv
# Listo: TSP_E4_150_4.csv -> 4_150.csv
# Listo: TSP_E4_150_5.csv -> 5_150.csv
# Listo: TSP_E4_150_6.csv -> 6_150.csv
# Listo: TSP_E4_150_7.csv -> 7_150.csv
# Listo: TSP_E4_150_8.csv -> 8_150.csv
# Listo: TSP_E4_150_9.csv -> 9_150.csv
# Listo: TSP_E4_200_1.csv -> 1_200.csv
# Listo: TSP_E4_200_10.csv -> 10_200.csv
# Listo: TSP_E4_200_2.csv -> 2_200.csv
# Listo: TSP_E4_200_3.csv -> 3_200.csv
# Listo: TSP_E4_200_4.csv -> 4_200.csv
# Listo: TSP_E4_200_5.csv -> 5_200.csv
# Listo: TSP_E4_200_6.csv -> 6_200.csv
# Listo: TSP_E4_200_7.csv -> 7_200.csv
# Listo: TSP_E4_200_8.csv -> 8_200.csv
# Listo: TSP_E4_200_9.csv -> 9_200.csv
# Listo: TSP_E4_40_1.csv -> 1_40.csv
# Listo: TSP_E4_40_10.csv -> 10_40.csv
# Listo: TSP_E4_40_2.csv -> 2_40.csv
# Listo: TSP_E4_40_3.csv -> 3_40.csv
# Listo: TSP_E4_40_4.csv -> 4_40.csv
# Listo: TSP_E4_40_5.csv -> 5_40.csv
# Listo: TSP_E4_40_6.csv -> 6_40.csv
# Listo: TSP_E4_40_7.csv -> 7_40.csv
# Listo: TSP_E4_40_8.csv -> 8_40.csv
# Listo: TSP_E4_40_9.csv -> 9_40.csv

# %% [markdown]
# ## Aproximacion con cp cuando es necesario

# %%
# ==== CONFIGURA AQUÍ ====
INPUT_DIR   = 'redes'       # carpeta que ya contiene tus CSV con lat/lon (salida del 1er script)
API_KEY     = "tu api aqui" # o usa variable de entorno GOOGLE_MAPS_API_KEY
PAUSA_SEG   = 0.5           # pausa corta entre llamadas para no saturar la API
IDIOMA      = "es"
# ========================

def limpiar(x):
    return (str(x).strip()) if x is not None else ""

def _hit_geocode(url, params):
    try:
        r = requests.get(url, params=params, timeout=20)
        r.raise_for_status()
        data = r.json()
        status = data.get("status", "UNKNOWN_ERROR")
        if status == "OK" and data.get("results"):
            loc = data["results"][0]["geometry"]["location"]
            return loc.get("lat"), loc.get("lng"), "OK"
        return "", "", status
    except requests.RequestException as e:
        return "", "", f"ERROR_HTTP: {e}"

def geocodificar_cp(cp, ciudad=None):
    """
    Obtiene coordenadas aproximadas del centro del C.P. (y opcionalmente ciudad) en MX.
    """
    if not cp:
        return "", "", "SIN_CP"

    url = "https://maps.googleapis.com/maps/api/geocode/json"
    comps = ["country:MX", f"postal_code:{cp}"]
    if ciudad:
        comps.append(f"locality:{ciudad}")

    params = {
        "key": API_KEY,
        "region": "mx",
        "language": IDIOMA,
        "components": "|".join(comps),
        # Con 'address' el geocoder intenta resolver el CP directamente
        "address": f"{cp}, México"
    }
    return _hit_geocode(url, params)

def necesita_aprox(row):
    """
    Decide si una fila necesita aproximación por CP:
    - lat o lon vacíos
    - o geo_status indica fallo típico del 1er script
    """
    lat = limpiar(row.get("lat"))
    lon = limpiar(row.get("lon"))
    if not lat or not lon:
        return True

    status = limpiar(row.get("geo_status"))
    if status and status.upper() in {"ZERO_RESULTS", "NOT_FOUND", "INVALID_REQUEST", "UNKNOWN_ERROR"}:
        return True

    return False

def procesar_archivo(path_csv):
    # Leer completo y reescribir a un temporal
    with open(path_csv, "r", encoding="utf-8", newline="") as f_in:
        reader = csv.DictReader(f_in)
        fieldnames = list(reader.fieldnames)

        # Asegurar la nueva columna al final
        if "aprox_por_cp" not in fieldnames:
            fieldnames.append("aprox_por_cp")

        tmp_path = path_csv + ".tmp"
        with open(tmp_path, "w", encoding="utf-8", newline="") as f_out:
            writer = csv.DictWriter(f_out, fieldnames=fieldnames)
            writer.writeheader()

            cache_cp = {}  # cache (cp|ciudad) -> (lat, lon, status)
            total = 0
            rellenadas = 0

            for row in reader:
                total += 1
                row.setdefault("aprox_por_cp", "0")  # por defecto, no se usó CP

                if necesita_aprox(row):
                    cp = limpiar(row.get("C.P."))
                    ciudad = limpiar(row.get("Ciudad"))

                    clave = (cp, ciudad.lower())
                    if clave in cache_cp:
                        lat_cp, lon_cp, st_cp = cache_cp[clave]
                    else:
                        lat_cp, lon_cp, st_cp = geocodificar_cp(cp, ciudad if ciudad else None)
                        cache_cp[clave] = (lat_cp, lon_cp, st_cp)
                        time.sleep(PAUSA_SEG)

                    if st_cp == "OK" and lat_cp and lon_cp:
                        # Rellenar coordenadas y marcar que se usó CP
                        row["lat"] = lat_cp
                        row["lon"] = lon_cp
                        row["aprox_por_cp"] = "1"
                        rellenadas += 1
                    else:
                        # No se pudo aproximar; mantener como estaba
                        row["aprox_por_cp"] = "0"

                writer.writerow(row)

    # Reemplazar el original
    os.replace(tmp_path, path_csv)
    print(f"Archivo procesado: {os.path.basename(path_csv)} | filas: {total} | rellenadas_por_cp: {rellenadas}")

def main():
    if not API_KEY or API_KEY in ("TU_API_KEY_AQUI", "tu api aqui"):
        raise RuntimeError("Falta API_KEY. Exporta GOOGLE_MAPS_API_KEY o edítala en el script.")

    if not os.path.isdir(INPUT_DIR):
        raise RuntimeError(f"No existe la carpeta: {INPUT_DIR}")

    archivos = [f for f in os.listdir(INPUT_DIR) if f.lower().endswith(".csv")]
    if not archivos:
        print(f"No se encontraron CSV en: {INPUT_DIR}")
        return

    for fname in sorted(archivos):
        procesar_archivo(os.path.join(INPUT_DIR, fname))

if __name__ == "__main__":
    main()

# %% [markdown]
# ## Funciones auxiliares

# %%
def haversine_distance(coord1, coord2):
    R = 6371
    lat1, lon1 = coord1
    lat2, lon2 = coord2

    lat1_rad, lon1_rad = radians(lat1), radians(lon1)
    lat2_rad, lon2_rad = radians(lat2), radians(lon2)

    dlat = lat2_rad - lat1_rad
    dlon = lon2_rad - lon1_rad

    a = sin(dlat/2)**2 + cos(lat1_rad)*cos(lat2_rad)*sin(dlon/2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))
    return R * c

def crear_matriz_distancias(df_red):
    coordenadas = df_red[['lat', 'lon']].values
    n = len(coordenadas)
    matriz_distancias = np.zeros((n, n))

    for i in range(n):
        for j in range(i, n):
            distancia = haversine_distance(coordenadas[i], coordenadas[j])
            matriz_distancias[i, j] = distancia
            matriz_distancias[j, i] = distancia

    return matriz_distancias

# %% [markdown]
# ## Algoritmo genético

# %%
def inicializar_poblacion(tamano_poblacion, indices_ciudades):
    poblacion = []
    for _ in range(tamano_poblacion):
        individuo = indices_ciudades.copy()
        random.shuffle(individuo)
        poblacion.append(individuo)
    return poblacion

def calcular_aptitud(individuo, matriz_distancias):
    distancia_total = 0
    for i in range(len(individuo)):
        ciudad_origen = individuo[i]
        ciudad_destino = individuo[(i + 1) % len(individuo)]
        distancia_total += matriz_distancias[ciudad_origen][ciudad_destino]
    return distancia_total

def seleccionar_padres(poblacion, aptitudes, num_padres):
    padres_indices = np.argsort(aptitudes)[:num_padres]
    padres = [poblacion[i] for i in padres_indices]
    return padres

def cruzar_padres(padre1, padre2):
    tamano = len(padre1)
    inicio, fin = sorted(random.sample(range(tamano), 2))
    hijo = [None]*tamano
    hijo[inicio:fin+1] = padre1[inicio:fin+1]

    pointer = 0
    for i in range(tamano):
        if hijo[i] is None:
            while padre2[pointer] in hijo:
                pointer += 1
            hijo[i] = padre2[pointer]
            pointer += 1
    return hijo

def mutar_individuo(individuo, tasa_mutacion):
    for i in range(len(individuo)):
        if random.random() < tasa_mutacion:
            j = random.randint(0, len(individuo)-1)
            individuo[i], individuo[j] = individuo[j], individuo[i]
    return individuo

def algoritmo_genetico_tsp(matriz_distancias, tamano_poblacion=100, num_generaciones=100, tasa_mutacion=0.01):
    indices_ciudades = list(range(len(matriz_distancias)))
    poblacion = inicializar_poblacion(tamano_poblacion, indices_ciudades)
    mejor_distancia = float('inf')
    mejor_ruta = None

    for generacion in range(num_generaciones):
        aptitudes = [calcular_aptitud(individuo, matriz_distancias) for individuo in poblacion]
        distancia_actual = min(aptitudes)
        if distancia_actual < mejor_distancia:
            mejor_distancia = distancia_actual
            mejor_ruta = poblacion[np.argmin(aptitudes)]

        num_padres = tamano_poblacion // 2
        padres = seleccionar_padres(poblacion, aptitudes, num_padres)

        siguiente_generacion = []
        while len(siguiente_generacion) < tamano_poblacion:
            padre1, padre2 = random.sample(padres, 2)
            hijo = cruzar_padres(padre1, padre2)
            hijo = mutar_individuo(hijo, tasa_mutacion)
            siguiente_generacion.append(hijo)

        poblacion = siguiente_generacion

        if (generacion + 1) % 50 == 0:
            print(f"Generación {generacion + 1}: Mejor distancia = {mejor_distancia:.2f} km")

    return mejor_ruta, mejor_distancia

# %% [markdown]
# ## Algoritmo colonia de hormigas (ACO)

# %%
def calcular_heuristica(costos):
    num_nodos = costos.shape[0]
    heuristica = np.zeros_like(costos)
    for i in range(num_nodos):
        for j in range(num_nodos):
            if costos[i, j] > 0 and not np.isinf(costos[i, j]):
                heuristica[i, j] = 1 / costos[i, j]
            else:
                heuristica[i, j] = 0
    return heuristica

def calcular_probabilidades(feromonas, heuristica, nodo_actual, visitados, alpha, beta):
    num_nodos = len(feromonas)
    probabilidades = np.zeros(num_nodos)
    for j in range(num_nodos):
        if j not in visitados:
            probabilidades[j] = (feromonas[nodo_actual, j] ** alpha) * (heuristica[nodo_actual, j] ** beta)
    suma_probabilidades = np.sum(probabilidades)
    if suma_probabilidades == 0:
        return probabilidades
    return probabilidades / suma_probabilidades

def construir_camino(feromonas, heuristica, costos, alpha, beta):
    num_nodos = costos.shape[0]
    nodo_actual = random.randint(0, num_nodos - 1)
    camino = [nodo_actual]
    costo_total = 0
    visitados = set(camino)

    while len(camino) < num_nodos:
        probabilidades = calcular_probabilidades(feromonas, heuristica, nodo_actual, visitados, alpha, beta)
        if np.sum(probabilidades) == 0:
            nodos_no_visitados = list(set(range(num_nodos)) - visitados)
            siguiente_nodo = random.choice(nodos_no_visitados)
        else:
            siguiente_nodo = random.choices(range(num_nodos), weights=probabilidades, k=1)[0]
        costo_total += costos[nodo_actual, siguiente_nodo]
        camino.append(siguiente_nodo)
        visitados.add(siguiente_nodo)
        nodo_actual = siguiente_nodo

    costo_total += costos[camino[-1], camino[0]]
    camino.append(camino[0])

    return camino, costo_total

def actualizar_feromonas(feromonas, soluciones, rho):
    feromonas *= (1 - rho)
    for camino, costo in soluciones:
        for i in range(len(camino) - 1):
            feromonas[camino[i], camino[i + 1]] += 1 / costo

def ACO(costos, num_hormigas=500, num_iteraciones=100, alpha=1.0, beta=2.0, rho=0.5):
    num_nodos = costos.shape[0]
    mejor_camino = None
    mejor_costo = float('inf')

    feromonas = np.ones((num_nodos, num_nodos)) * 0.1
    heuristica = calcular_heuristica(costos)

    for iteracion in range(num_iteraciones):
        soluciones = []
        for _ in range(num_hormigas):
            camino, costo = construir_camino(feromonas, heuristica, costos, alpha, beta)
            soluciones.append((camino, costo))
            if costo < mejor_costo:
                mejor_camino = camino
                mejor_costo = costo

        actualizar_feromonas(feromonas, soluciones, rho)

        if (iteracion + 1) % 10 == 0:
            print(f"Iteración {iteracion+1}: Mejor costo hasta ahora = {mejor_costo:.2f} km")

    return mejor_camino, mejor_costo

# %% [markdown]
# ## Procesar las redes

# %%
def procesar_redes(archivo):
    df_red = pd.read_csv(archivo)

    matriz_distancias = crear_matriz_distancias(df_red)

    start_genetico = time.time()
    mejor_ruta_genetico, mejor_distancia_genetico = algoritmo_genetico_tsp(matriz_distancias, tamano_poblacion=100, num_generaciones=500, tasa_mutacion=0.01)
    end_genetico = time.time()

    start_aco = time.time()
    mejor_ruta_aco, mejor_distancia_aco = ACO(matriz_distancias, num_hormigas=500, num_iteraciones=100, alpha=1.0, beta=2.0, rho=0.5)
    end_aco = time.time()

    tiempo_genetico = end_genetico - start_genetico
    tiempo_aco = end_aco - start_aco

    return mejor_ruta_genetico, mejor_distancia_genetico, tiempo_genetico, mejor_ruta_aco, mejor_distancia_aco, tiempo_aco

def crear_visualizacion(df_red, mejor_ruta, nombre_archivo):
    coordenadas = df_red[['lat', 'lon']].values
    ruta_coordenadas = coordenadas[mejor_ruta]
    ruta_coordenadas = np.vstack([ruta_coordenadas, ruta_coordenadas[0]])

    centro_lat = np.mean(coordenadas[:, 0])
    centro_lon = np.mean(coordenadas[:, 1])
    mapa = folium.Map(location=[centro_lat, centro_lon], zoom_start=12)

    for idx, coord in enumerate(ruta_coordenadas[:-1]):
        folium.Marker(location=coord, popup=f"Parada {idx + 1}").add_to(mapa)

    folium.PolyLine(ruta_coordenadas, color="blue", weight=2.5, opacity=1).add_to(mapa)

    return mapa.save(nombre_archivo)

def generar_archivos_inclusion(archivo):
        df_red = pd.read_csv(archivo)
        matriz_distancias = crear_matriz_distancias(df_red)
        n = len(df_red)

        # Crear el archivo de inclusión
        nombre_archivo_inc = f"{path_de_resultados}/{archivo.split('/')[-1].split('.')[0]}/gams_{archivo.split('/')[-1].split('.')[0]}.inc"
        with open(nombre_archivo_inc, 'w') as f:
            # Escribir encabezado (índices de columnas)
            f.write("    ")  # Espacio para el índice de filas
            for j in range(n):
                f.write(f"{j:<8}")  # Alinear columnas con espacio fijo
            f.write("\n")

            # Escribir filas de la matriz
            for i in range(n):
                f.write(f"{i:<4}")  # Índice de la fila
                for j in range(n):
                    f.write(f"{matriz_distancias[i][j]:<8.1f}")  # Valor de la matriz con 1 decimal
                f.write("\n")

        print(f"Archivo de inclusión generado: {nombre_archivo_inc}")

def procesar_archivo(archivo):
    print(f"Procesando archivo: {archivo}")
    df_red = pd.read_csv(archivo)

    path_de_resultado_base = f"{path_de_resultados}/{archivo.split('/')[-1].split('.')[0]}"
    os.makedirs(path_de_resultado_base, exist_ok=True)

    path_de_resultado_json = f"{path_de_resultado_base}/{archivo.split('/')[-1].split('.')[0]}.json"
    path_de_visualizacion_genetico = f"{path_de_resultado_base}/{archivo.split('/')[-1].split('.')[0]}_genetico.html"
    path_de_visualizacion_aco = f"{path_de_resultado_base}/{archivo.split('/')[-1].split('.')[0]}_aco.html"

    mejor_ruta_genetico, mejor_distancia_genetico, tiempo_genetico, mejor_ruta_aco, mejor_distancia_aco, tiempo_aco = procesar_redes(archivo)

    # Generar resultados en un archivo json
    with open(path_de_resultado_json, "w") as f:
        json.dump({
            "genetico": {
                "ruta": mejor_ruta_genetico,
                "distancia": mejor_distancia_genetico,
                "tiempo": tiempo_genetico
            },
            "aco": {
                "ruta": mejor_ruta_aco,
                "distancia": mejor_distancia_aco,
                "tiempo": tiempo_aco
            }
        }, f)

    # Crear visualización de la mejor ruta encontrada por el algoritmo genético
    crear_visualizacion(df_red, mejor_ruta_genetico, path_de_visualizacion_genetico)
    crear_visualizacion(df_red, mejor_ruta_aco, path_de_visualizacion_aco)
    print(f"Resultados guardados en: {path_de_resultado_base}\n\n")

# Procesar cada archivo de red
paths = [f"{path_de_redes}/{archivo}" for archivo in os.listdir(path_de_redes)]
paths_sorted = sorted(paths, key=lambda x: int(x.split('/')[1].split('_')[0]))

for archivo in paths_sorted:
    procesar_archivo(archivo)
    generar_archivos_inclusion(archivo)
# Out:
# Procesando archivo: redes/1_100.csv
# Generación 50: Mejor distancia = 740.97 km
# Generación 100: Mejor distancia = 740.97 km
# Generación 150: Mejor distancia = 740.97 km
# Generación 200: Mejor distancia = 740.97 km
# Generación 250: Mejor distancia = 699.74 km
# Generación 300: Mejor distancia = 678.62 km
# Generación 350: Mejor distancia = 678.62 km
# Generación 400: Mejor distancia = 678.62 km
# Generación 450: Mejor distancia = 678.62 km
# Generación 500: Mejor distancia = 678.62 km
# Iteración 10: Mejor costo hasta ahora = 219.93 km
# Iteración 20: Mejor costo hasta ahora = 211.13 km
# Iteración 30: Mejor costo hasta ahora = 211.13 km
# Iteración 40: Mejor costo hasta ahora = 209.81 km
# Iteración 50: Mejor costo hasta ahora = 209.81 km
# Iteración 60: Mejor costo hasta ahora = 209.81 km
# Iteración 70: Mejor costo hasta ahora = 209.81 km
# Iteración 80: Mejor costo hasta ahora = 209.81 km
# Iteración 90: Mejor costo hasta ahora = 209.81 km
# Iteración 100: Mejor costo hasta ahora = 209.81 km
# Resultados guardados en: resultados/1_100
#
#
# Archivo de inclusión generado: resultados/1_100/gams_1_100.inc
# Procesando archivo: redes/1_150.csv
# Generación 50: Mejor distancia = 1185.37 km
# Generación 100: Mejor distancia = 1185.37 km
# Generación 150: Mejor distancia = 1185.37 km
# Generación 200: Mejor distancia = 1185.37 km
# Generación 250: Mejor distancia = 1185.37 km
# Generación 300: Mejor distancia = 1185.37 km
# Generación 350: Mejor distancia = 1185.37 km
# Generación 400: Mejor distancia = 1185.37 km
# Generación 450: Mejor distancia = 1185.37 km
# Generación 500: Mejor distancia = 1185.37 km
# Iteración 10: Mejor costo hasta ahora = 267.29 km
# Iteración 20: Mejor costo hasta ahora = 253.26 km
# Iteración 30: Mejor costo hasta ahora = 249.89 km
# Iteración 40: Mejor costo hasta ahora = 249.89 km
# Iteración 50: Mejor costo hasta ahora = 242.68 km
# Iteración 60: Mejor costo hasta ahora = 242.68 km
# Iteración 70: Mejor costo hasta ahora = 242.68 km
# Iteración 80: Mejor costo hasta ahora = 242.68 km
# Iteración 90: Mejor costo hasta ahora = 238.96 km
# Iteración 100: Mejor costo hasta ahora = 238.96 km
# Resultados guardados en: resultados/1_150
#
#
# Archivo de inclusión generado: resultados/1_150/gams_1_150.inc
# Procesando archivo: redes/1_200.csv
# Generación 50: Mejor distancia = 1772.83 km
# Generación 100: Mejor distancia = 1757.63 km
# Generación 150: Mejor distancia = 1726.33 km
# Generación 200: Mejor distancia = 1726.33 km
# Generación 250: Mejor distancia = 1717.31 km
# Generación 300: Mejor distancia = 1709.61 km
# Generación 350: Mejor distancia = 1709.61 km
# Generación 400: Mejor distancia = 1709.61 km
# Generación 450: Mejor distancia = 1709.61 km
# Generación 500: Mejor distancia = 1709.61 km
# Iteración 10: Mejor costo hasta ahora = 351.00 km
# Iteración 20: Mejor costo hasta ahora = 340.61 km
# Iteración 30: Mejor costo hasta ahora = 337.80 km
# Iteración 40: Mejor costo hasta ahora = 335.54 km
# Iteración 50: Mejor costo hasta ahora = 335.54 km
# Iteración 60: Mejor costo hasta ahora = 335.54 km
# Iteración 70: Mejor costo hasta ahora = 335.54 km
# Iteración 80: Mejor costo hasta ahora = 321.85 km
# Iteración 90: Mejor costo hasta ahora = 321.85 km
# Iteración 100: Mejor costo hasta ahora = 321.85 km
# Resultados guardados en: resultados/1_200
#
#
# Archivo de inclusión generado: resultados/1_200/gams_1_200.inc
# Procesando archivo: redes/1_40.csv
# Generación 50: Mejor distancia = 260.56 km
# Generación 100: Mejor distancia = 219.85 km
# Generación 150: Mejor distancia = 173.48 km
# Generación 200: Mejor distancia = 156.48 km
# Generación 250: Mejor distancia = 156.48 km
# Generación 300: Mejor distancia = 148.21 km
# Generación 350: Mejor distancia = 148.21 km
# Generación 400: Mejor distancia = 144.79 km
# Generación 450: Mejor distancia = 143.79 km
# Generación 500: Mejor distancia = 143.79 km
# Iteración 10: Mejor costo hasta ahora = 112.43 km
# Iteración 20: Mejor costo hasta ahora = 112.43 km
# Iteración 30: Mejor costo hasta ahora = 112.35 km
# Iteración 40: Mejor costo hasta ahora = 112.35 km
# Iteración 50: Mejor costo hasta ahora = 112.35 km
# Iteración 60: Mejor costo hasta ahora = 112.35 km
# Iteración 70: Mejor costo hasta ahora = 112.35 km
# Iteración 80: Mejor costo hasta ahora = 112.35 km
# Iteración 90: Mejor costo hasta ahora = 112.35 km
# Iteración 100: Mejor costo hasta ahora = 112.35 km
# Resultados guardados en: resultados/1_40
#
#
# Archivo de inclusión generado: resultados/1_40/gams_1_40.inc
# Procesando archivo: redes/2_100.csv
# Generación 50: Mejor distancia = 745.61 km
# Generación 100: Mejor distancia = 745.61 km
# Generación 150: Mejor distancia = 726.41 km
# Generación 200: Mejor distancia = 726.41 km
# Generación 250: Mejor distancia = 701.56 km
# Generación 300: Mejor distancia = 701.56 km
# Generación 350: Mejor distancia = 701.56 km
# Generación 400: Mejor distancia = 701.56 km
# Generación 450: Mejor distancia = 701.56 km
# Generación 500: Mejor distancia = 701.56 km
# Iteración 10: Mejor costo hasta ahora = 176.88 km
# Iteración 20: Mejor costo hasta ahora = 171.78 km
# Iteración 30: Mejor costo hasta ahora = 170.81 km
# Iteración 40: Mejor costo hasta ahora = 170.10 km
# Iteración 50: Mejor costo hasta ahora = 169.19 km
# Iteración 60: Mejor costo hasta ahora = 166.81 km
# Iteración 70: Mejor costo hasta ahora = 166.81 km
# Iteración 80: Mejor costo hasta ahora = 166.81 km
# Iteración 90: Mejor costo hasta ahora = 166.81 km
# Iteración 100: Mejor costo hasta ahora = 166.81 km
# Resultados guardados en: resultados/2_100
#
#
# Archivo de inclusión generado: resultados/2_100/gams_2_100.inc
# Procesando archivo: redes/2_150.csv
# Generación 50: Mejor distancia = 1324.49 km
# Generación 100: Mejor distancia = 1288.86 km
# Generación 150: Mejor distancia = 1288.86 km
# Generación 200: Mejor distancia = 1262.75 km
# Generación 250: Mejor distancia = 1262.75 km
# Generación 300: Mejor distancia = 1262.75 km
# Generación 350: Mejor distancia = 1262.75 km
# Generación 400: Mejor distancia = 1262.75 km
# Generación 450: Mejor distancia = 1262.75 km
# Generación 500: Mejor distancia = 1262.75 km
# Iteración 10: Mejor costo hasta ahora = 323.05 km
# Iteración 20: Mejor costo hasta ahora = 315.80 km
# Iteración 30: Mejor costo hasta ahora = 311.25 km
# Iteración 40: Mejor costo hasta ahora = 311.25 km
# Iteración 50: Mejor costo hasta ahora = 311.25 km
# Iteración 60: Mejor costo hasta ahora = 311.25 km
# Iteración 70: Mejor costo hasta ahora = 311.25 km
# Iteración 80: Mejor costo hasta ahora = 310.06 km
# Iteración 90: Mejor costo hasta ahora = 310.06 km
# Iteración 100: Mejor costo hasta ahora = 310.06 km
# Resultados guardados en: resultados/2_150
#
#
# Archivo de inclusión generado: resultados/2_150/gams_2_150.inc
# Procesando archivo: redes/2_200.csv
# Generación 50: Mejor distancia = 1765.59 km
# Generación 100: Mejor distancia = 1760.62 km
# Generación 150: Mejor distancia = 1734.26 km
# Generación 200: Mejor distancia = 1701.03 km
# Generación 250: Mejor distancia = 1701.03 km
# Generación 300: Mejor distancia = 1701.03 km
# Generación 350: Mejor distancia = 1676.15 km
# Generación 400: Mejor distancia = 1624.84 km
# Generación 450: Mejor distancia = 1624.84 km
# Generación 500: Mejor distancia = 1624.84 km
# Iteración 10: Mejor costo hasta ahora = 317.01 km
# Iteración 20: Mejor costo hasta ahora = 306.96 km
# Iteración 30: Mejor costo hasta ahora = 306.86 km
# Iteración 40: Mejor costo hasta ahora = 298.97 km
# Iteración 50: Mejor costo hasta ahora = 298.97 km
# Iteración 60: Mejor costo hasta ahora = 298.97 km
# Iteración 70: Mejor costo hasta ahora = 298.97 km
# Iteración 80: Mejor costo hasta ahora = 298.97 km
# Iteración 90: Mejor costo hasta ahora = 298.97 km
# Iteración 100: Mejor costo hasta ahora = 298.97 km
# Resultados guardados en: resultados/2_200
#
#
# Archivo de inclusión generado: resultados/2_200/gams_2_200.inc
# Procesando archivo: redes/2_40.csv
# Generación 50: Mejor distancia = 304.82 km
# Generación 100: Mejor distancia = 240.97 km
# Generación 150: Mejor distancia = 199.24 km
# Generación 200: Mejor distancia = 191.99 km
# Generación 250: Mejor distancia = 189.74 km
# Generación 300: Mejor distancia = 184.23 km
# Generación 350: Mejor distancia = 173.75 km
# Generación 400: Mejor distancia = 172.49 km
# Generación 450: Mejor distancia = 172.25 km
# Generación 500: Mejor distancia = 169.98 km
# Iteración 10: Mejor costo hasta ahora = 159.21 km
# Iteración 20: Mejor costo hasta ahora = 158.34 km
# Iteración 30: Mejor costo hasta ahora = 157.02 km
# Iteración 40: Mejor costo hasta ahora = 155.32 km
# Iteración 50: Mejor costo hasta ahora = 155.32 km
# Iteración 60: Mejor costo hasta ahora = 155.32 km
# Iteración 70: Mejor costo hasta ahora = 153.72 km
# Iteración 80: Mejor costo hasta ahora = 153.72 km
# Iteración 90: Mejor costo hasta ahora = 153.72 km
# Iteración 100: Mejor costo hasta ahora = 153.72 km
# Resultados guardados en: resultados/2_40
#
#
# Archivo de inclusión generado: resultados/2_40/gams_2_40.inc
# Procesando archivo: redes/3_100.csv
# Generación 50: Mejor distancia = 836.48 km
# Generación 100: Mejor distancia = 810.05 km
# Generación 150: Mejor distancia = 799.14 km
# Generación 200: Mejor distancia = 799.14 km
# Generación 250: Mejor distancia = 799.14 km
# Generación 300: Mejor distancia = 799.14 km
# Generación 350: Mejor distancia = 799.14 km
# Generación 400: Mejor distancia = 799.14 km
# Generación 450: Mejor distancia = 799.14 km
# Generación 500: Mejor distancia = 799.14 km
# Iteración 10: Mejor costo hasta ahora = 253.44 km
# Iteración 20: Mejor costo hasta ahora = 245.89 km
# Iteración 30: Mejor costo hasta ahora = 240.40 km
# Iteración 40: Mejor costo hasta ahora = 240.40 km
# Iteración 50: Mejor costo hasta ahora = 240.40 km
# Iteración 60: Mejor costo hasta ahora = 236.53 km
# Iteración 70: Mejor costo hasta ahora = 236.53 km
# Iteración 80: Mejor costo hasta ahora = 236.53 km
# Iteración 90: Mejor costo hasta ahora = 236.53 km
# Iteración 100: Mejor costo hasta ahora = 236.53 km
# Resultados guardados en: resultados/3_100
#
#
# Archivo de inclusión generado: resultados/3_100/gams_3_100.inc
# Procesando archivo: redes/3_150.csv
# Generación 50: Mejor distancia = 1202.22 km
# Generación 100: Mejor distancia = 1177.69 km
# Generación 150: Mejor distancia = 1172.82 km
# Generación 200: Mejor distancia = 1172.82 km
# Generación 250: Mejor distancia = 1172.82 km
# Generación 300: Mejor distancia = 1172.82 km
# Generación 350: Mejor distancia = 1172.82 km
# Generación 400: Mejor distancia = 1172.82 km
# Generación 450: Mejor distancia = 1172.82 km
# Generación 500: Mejor distancia = 1172.82 km
# Iteración 10: Mejor costo hasta ahora = 217.14 km
# Iteración 20: Mejor costo hasta ahora = 210.36 km
# Iteración 30: Mejor costo hasta ahora = 207.23 km
# Iteración 40: Mejor costo hasta ahora = 207.23 km
# Iteración 50: Mejor costo hasta ahora = 207.23 km
# Iteración 60: Mejor costo hasta ahora = 206.30 km
# Iteración 70: Mejor costo hasta ahora = 206.30 km
# Iteración 80: Mejor costo hasta ahora = 206.30 km
# Iteración 90: Mejor costo hasta ahora = 200.56 km
# Iteración 100: Mejor costo hasta ahora = 200.56 km
# Resultados guardados en: resultados/3_150
#
#
# Archivo de inclusión generado: resultados/3_150/gams_3_150.inc
# Procesando archivo: redes/3_200.csv
# Generación 50: Mejor distancia = 1788.50 km
# Generación 100: Mejor distancia = 1699.89 km
# Generación 150: Mejor distancia = 1699.89 km
# Generación 200: Mejor distancia = 1699.89 km
# Generación 250: Mejor distancia = 1699.89 km
# Generación 300: Mejor distancia = 1699.89 km
# Generación 350: Mejor distancia = 1699.89 km
# Generación 400: Mejor distancia = 1699.89 km
# Generación 450: Mejor distancia = 1699.89 km
# Generación 500: Mejor distancia = 1699.89 km
# Iteración 10: Mejor costo hasta ahora = 352.72 km
# Iteración 20: Mejor costo hasta ahora = 340.54 km
# Iteración 30: Mejor costo hasta ahora = 339.70 km
# Iteración 40: Mejor costo hasta ahora = 331.08 km
# Iteración 50: Mejor costo hasta ahora = 326.97 km
# Iteración 60: Mejor costo hasta ahora = 326.97 km
# Iteración 70: Mejor costo hasta ahora = 326.97 km
# Iteración 80: Mejor costo hasta ahora = 325.92 km
# Iteración 90: Mejor costo hasta ahora = 325.92 km
# Iteración 100: Mejor costo hasta ahora = 320.17 km
# Resultados guardados en: resultados/3_200
#
#
# Archivo de inclusión generado: resultados/3_200/gams_3_200.inc
# Procesando archivo: redes/3_40.csv
# Generación 50: Mejor distancia = 304.58 km
# Generación 100: Mejor distancia = 233.12 km
# Generación 150: Mejor distancia = 172.34 km
# Generación 200: Mejor distancia = 169.39 km
# Generación 250: Mejor distancia = 167.56 km
# Generación 300: Mejor distancia = 163.71 km
# Generación 350: Mejor distancia = 163.71 km
# Generación 400: Mejor distancia = 162.97 km
# Generación 450: Mejor distancia = 162.53 km
# Generación 500: Mejor distancia = 162.53 km
# Iteración 10: Mejor costo hasta ahora = 145.12 km
# Iteración 20: Mejor costo hasta ahora = 145.12 km
# Iteración 30: Mejor costo hasta ahora = 145.12 km
# Iteración 40: Mejor costo hasta ahora = 145.12 km
# Iteración 50: Mejor costo hasta ahora = 145.12 km
# Iteración 60: Mejor costo hasta ahora = 145.12 km
# Iteración 70: Mejor costo hasta ahora = 145.12 km
# Iteración 80: Mejor costo hasta ahora = 142.94 km
# Iteración 90: Mejor costo hasta ahora = 142.94 km
# Iteración 100: Mejor costo hasta ahora = 142.94 km
# Resultados guardados en: resultados/3_40
#
#
# Archivo de inclusión generado: resultados/3_40/gams_3_40.inc
# Procesando archivo: redes/4_100.csv
# Generación 50: Mejor distancia = 714.55 km
# Generación 100: Mejor distancia = 699.92 km
# Generación 150: Mejor distancia = 699.92 km
# Generación 200: Mejor distancia = 672.67 km
# Generación 250: Mejor distancia = 672.67 km
# Generación 300: Mejor distancia = 672.67 km
# Generación 350: Mejor distancia = 672.67 km
# Generación 400: Mejor distancia = 662.45 km
# Generación 450: Mejor distancia = 662.45 km
# Generación 500: Mejor distancia = 662.45 km
# Iteración 10: Mejor costo hasta ahora = 174.05 km
# Iteración 20: Mejor costo hasta ahora = 170.64 km
# Iteración 30: Mejor costo hasta ahora = 166.72 km
# Iteración 40: Mejor costo hasta ahora = 165.27 km
# Iteración 50: Mejor costo hasta ahora = 165.27 km
# Iteración 60: Mejor costo hasta ahora = 164.72 km
# Iteración 70: Mejor costo hasta ahora = 164.72 km
# Iteración 80: Mejor costo hasta ahora = 164.72 km
# Iteración 90: Mejor costo hasta ahora = 164.72 km
# Iteración 100: Mejor costo hasta ahora = 161.05 km
# Resultados guardados en: resultados/4_100
#
#
# Archivo de inclusión generado: resultados/4_100/gams_4_100.inc
# Procesando archivo: redes/4_150.csv
# Generación 50: Mejor distancia = 1226.52 km
# Generación 100: Mejor distancia = 1225.57 km
# Generación 150: Mejor distancia = 1181.68 km
# Generación 200: Mejor distancia = 1175.28 km
# Generación 250: Mejor distancia = 1175.28 km
# Generación 300: Mejor distancia = 1175.28 km
# Generación 350: Mejor distancia = 1175.28 km
# Generación 400: Mejor distancia = 1175.28 km
# Generación 450: Mejor distancia = 1175.28 km
# Generación 500: Mejor distancia = 1175.28 km
# Iteración 10: Mejor costo hasta ahora = 265.23 km
# Iteración 20: Mejor costo hasta ahora = 254.85 km
# Iteración 30: Mejor costo hasta ahora = 254.85 km
# Iteración 40: Mejor costo hasta ahora = 251.09 km
# Iteración 50: Mejor costo hasta ahora = 248.81 km
# Iteración 60: Mejor costo hasta ahora = 248.81 km
# Iteración 70: Mejor costo hasta ahora = 248.81 km
# Iteración 80: Mejor costo hasta ahora = 248.81 km
# Iteración 90: Mejor costo hasta ahora = 248.81 km
# Iteración 100: Mejor costo hasta ahora = 248.81 km
# Resultados guardados en: resultados/4_150
#
#
# Archivo de inclusión generado: resultados/4_150/gams_4_150.inc
# Procesando archivo: redes/4_200.csv
# Generación 50: Mejor distancia = 1823.80 km
# Generación 100: Mejor distancia = 1749.12 km
# Generación 150: Mejor distancia = 1749.12 km
# Generación 200: Mejor distancia = 1676.32 km
# Generación 250: Mejor distancia = 1676.32 km
# Generación 300: Mejor distancia = 1676.32 km
# Generación 350: Mejor distancia = 1676.32 km
# Generación 400: Mejor distancia = 1676.32 km
# Generación 450: Mejor distancia = 1676.32 km
# Generación 500: Mejor distancia = 1676.32 km
# Iteración 10: Mejor costo hasta ahora = 350.23 km
# Iteración 20: Mejor costo hasta ahora = 330.75 km
# Iteración 30: Mejor costo hasta ahora = 330.75 km
# Iteración 40: Mejor costo hasta ahora = 321.97 km
# Iteración 50: Mejor costo hasta ahora = 321.97 km
# Iteración 60: Mejor costo hasta ahora = 321.97 km
# Iteración 70: Mejor costo hasta ahora = 321.97 km
# Iteración 80: Mejor costo hasta ahora = 321.97 km
# Iteración 90: Mejor costo hasta ahora = 321.97 km
# Iteración 100: Mejor costo hasta ahora = 319.75 km
# Resultados guardados en: resultados/4_200
#
#
# Archivo de inclusión generado: resultados/4_200/gams_4_200.inc
# Procesando archivo: redes/4_40.csv
# Generación 50: Mejor distancia = 283.20 km
# Generación 100: Mejor distancia = 212.22 km
# Generación 150: Mejor distancia = 160.40 km
# Generación 200: Mejor distancia = 157.18 km
# Generación 250: Mejor distancia = 155.74 km
# Generación 300: Mejor distancia = 155.49 km
# Generación 350: Mejor distancia = 155.49 km
# Generación 400: Mejor distancia = 154.53 km
# Generación 450: Mejor distancia = 154.53 km
# Generación 500: Mejor distancia = 154.53 km
# Iteración 10: Mejor costo hasta ahora = 117.44 km
# Iteración 20: Mejor costo hasta ahora = 115.28 km
# Iteración 30: Mejor costo hasta ahora = 114.22 km
# Iteración 40: Mejor costo hasta ahora = 114.22 km
# Iteración 50: Mejor costo hasta ahora = 114.22 km
# Iteración 60: Mejor costo hasta ahora = 114.22 km
# Iteración 70: Mejor costo hasta ahora = 114.22 km
# Iteración 80: Mejor costo hasta ahora = 112.67 km
# Iteración 90: Mejor costo hasta ahora = 112.67 km
# Iteración 100: Mejor costo hasta ahora = 112.67 km
# Resultados guardados en: resultados/4_40
#
#
# Archivo de inclusión generado: resultados/4_40/gams_4_40.inc
# Procesando archivo: redes/5_100.csv
# Generación 50: Mejor distancia = 843.77 km
# Generación 100: Mejor distancia = 816.19 km
# Generación 150: Mejor distancia = 812.56 km
# Generación 200: Mejor distancia = 788.20 km
# Generación 250: Mejor distancia = 788.20 km
# Generación 300: Mejor distancia = 788.20 km
# Generación 350: Mejor distancia = 788.20 km
# Generación 400: Mejor distancia = 788.20 km
# Generación 450: Mejor distancia = 782.86 km
# Generación 500: Mejor distancia = 763.93 km
# Iteración 10: Mejor costo hasta ahora = 216.57 km
# Iteración 20: Mejor costo hasta ahora = 216.57 km
# Iteración 30: Mejor costo hasta ahora = 216.57 km
# Iteración 40: Mejor costo hasta ahora = 216.57 km
# Iteración 50: Mejor costo hasta ahora = 216.57 km
# Iteración 60: Mejor costo hasta ahora = 216.57 km
# Iteración 70: Mejor costo hasta ahora = 216.57 km
# Iteración 80: Mejor costo hasta ahora = 212.59 km
# Iteración 90: Mejor costo hasta ahora = 212.59 km
# Iteración 100: Mejor costo hasta ahora = 212.59 km
# Resultados guardados en: resultados/5_100
#
#
# Archivo de inclusión generado: resultados/5_100/gams_5_100.inc
# Procesando archivo: redes/5_150.csv
# Generación 50: Mejor distancia = 1298.76 km
# Generación 100: Mejor distancia = 1272.80 km
# Generación 150: Mejor distancia = 1262.13 km
# Generación 200: Mejor distancia = 1250.02 km
# Generación 250: Mejor distancia = 1245.14 km
# Generación 300: Mejor distancia = 1245.14 km
# Generación 350: Mejor distancia = 1245.14 km
# Generación 400: Mejor distancia = 1245.14 km
# Generación 450: Mejor distancia = 1240.31 km
# Generación 500: Mejor distancia = 1211.74 km
# Iteración 10: Mejor costo hasta ahora = 267.11 km
# Iteración 20: Mejor costo hasta ahora = 260.76 km
# Iteración 30: Mejor costo hasta ahora = 247.11 km
# Iteración 40: Mejor costo hasta ahora = 247.11 km
# Iteración 50: Mejor costo hasta ahora = 247.11 km
# Iteración 60: Mejor costo hasta ahora = 247.11 km
# Iteración 70: Mejor costo hasta ahora = 247.11 km
# Iteración 80: Mejor costo hasta ahora = 247.11 km
# Iteración 90: Mejor costo hasta ahora = 247.11 km
# Iteración 100: Mejor costo hasta ahora = 247.11 km
# Resultados guardados en: resultados/5_150
#
#
# Archivo de inclusión generado: resultados/5_150/gams_5_150.inc
# Procesando archivo: redes/5_200.csv
# Generación 50: Mejor distancia = 1790.22 km
# Generación 100: Mejor distancia = 1764.71 km
# Generación 150: Mejor distancia = 1764.71 km
# Generación 200: Mejor distancia = 1699.95 km
# Generación 250: Mejor distancia = 1699.95 km
# Generación 300: Mejor distancia = 1699.95 km
# Generación 350: Mejor distancia = 1677.23 km
# Generación 400: Mejor distancia = 1677.23 km
# Generación 450: Mejor distancia = 1677.23 km
# Generación 500: Mejor distancia = 1677.23 km
# Iteración 10: Mejor costo hasta ahora = 310.46 km
# Iteración 20: Mejor costo hasta ahora = 301.99 km
# Iteración 30: Mejor costo hasta ahora = 300.02 km
# Iteración 40: Mejor costo hasta ahora = 300.02 km
# Iteración 50: Mejor costo hasta ahora = 300.02 km
# Iteración 60: Mejor costo hasta ahora = 300.02 km
# Iteración 70: Mejor costo hasta ahora = 300.02 km
# Iteración 80: Mejor costo hasta ahora = 300.02 km
# Iteración 90: Mejor costo hasta ahora = 300.02 km
# Iteración 100: Mejor costo hasta ahora = 300.02 km
# Resultados guardados en: resultados/5_200
#
#
# Archivo de inclusión generado: resultados/5_200/gams_5_200.inc
# Procesando archivo: redes/5_40.csv
# Generación 50: Mejor distancia = 273.75 km
# Generación 100: Mejor distancia = 199.86 km
# Generación 150: Mejor distancia = 190.69 km
# Generación 200: Mejor distancia = 180.81 km
# Generación 250: Mejor distancia = 177.94 km
# Generación 300: Mejor distancia = 170.24 km
# Generación 350: Mejor distancia = 170.24 km
# Generación 400: Mejor distancia = 170.16 km
# Generación 450: Mejor distancia = 170.16 km
# Generación 500: Mejor distancia = 169.32 km
# Iteración 10: Mejor costo hasta ahora = 158.95 km
# Iteración 20: Mejor costo hasta ahora = 157.53 km
# Iteración 30: Mejor costo hasta ahora = 154.02 km
# Iteración 40: Mejor costo hasta ahora = 154.02 km
# Iteración 50: Mejor costo hasta ahora = 154.02 km
# Iteración 60: Mejor costo hasta ahora = 154.02 km
# Iteración 70: Mejor costo hasta ahora = 154.02 km
# Iteración 80: Mejor costo hasta ahora = 154.02 km
# Iteración 90: Mejor costo hasta ahora = 154.02 km
# Iteración 100: Mejor costo hasta ahora = 154.02 km
# Resultados guardados en: resultados/5_40
#
#
# Archivo de inclusión generado: resultados/5_40/gams_5_40.inc
# Procesando archivo: redes/6_100.csv
# Generación 50: Mejor distancia = 894.72 km
# Generación 100: Mejor distancia = 836.67 km
# Generación 150: Mejor distancia = 836.67 km
# Generación 200: Mejor distancia = 800.91 km
# Generación 250: Mejor distancia = 800.91 km
# Generación 300: Mejor distancia = 800.91 km
# Generación 350: Mejor distancia = 800.91 km
# Generación 400: Mejor distancia = 800.91 km
# Generación 450: Mejor distancia = 800.91 km
# Generación 500: Mejor distancia = 800.91 km
# Iteración 10: Mejor costo hasta ahora = 260.94 km
# Iteración 20: Mejor costo hasta ahora = 245.70 km
# Iteración 30: Mejor costo hasta ahora = 245.70 km
# Iteración 40: Mejor costo hasta ahora = 245.70 km
# Iteración 50: Mejor costo hasta ahora = 245.70 km
# Iteración 60: Mejor costo hasta ahora = 242.92 km
# Iteración 70: Mejor costo hasta ahora = 239.97 km
# Iteración 80: Mejor costo hasta ahora = 239.97 km
# Iteración 90: Mejor costo hasta ahora = 239.97 km
# Iteración 100: Mejor costo hasta ahora = 239.02 km
# Resultados guardados en: resultados/6_100
#
#
# Archivo de inclusión generado: resultados/6_100/gams_6_100.inc
# Procesando archivo: redes/6_150.csv
# Generación 50: Mejor distancia = 1362.08 km
# Generación 100: Mejor distancia = 1283.01 km
# Generación 150: Mejor distancia = 1268.86 km
# Generación 200: Mejor distancia = 1268.86 km
# Generación 250: Mejor distancia = 1268.86 km
# Generación 300: Mejor distancia = 1236.33 km
# Generación 350: Mejor distancia = 1236.33 km
# Generación 400: Mejor distancia = 1236.33 km
# Generación 450: Mejor distancia = 1236.33 km
# Generación 500: Mejor distancia = 1236.33 km
# Iteración 10: Mejor costo hasta ahora = 274.41 km
# Iteración 20: Mejor costo hasta ahora = 265.80 km
# Iteración 30: Mejor costo hasta ahora = 264.30 km
# Iteración 40: Mejor costo hasta ahora = 264.30 km
# Iteración 50: Mejor costo hasta ahora = 263.42 km
# Iteración 60: Mejor costo hasta ahora = 263.42 km
# Iteración 70: Mejor costo hasta ahora = 263.42 km
# Iteración 80: Mejor costo hasta ahora = 256.69 km
# Iteración 90: Mejor costo hasta ahora = 256.69 km
# Iteración 100: Mejor costo hasta ahora = 256.69 km
# Resultados guardados en: resultados/6_150
#
#
# Archivo de inclusión generado: resultados/6_150/gams_6_150.inc
# Procesando archivo: redes/6_200.csv
# Generación 50: Mejor distancia = 1821.82 km
# Generación 100: Mejor distancia = 1760.55 km
# Generación 150: Mejor distancia = 1751.90 km
# Generación 200: Mejor distancia = 1722.04 km
# Generación 250: Mejor distancia = 1696.45 km
# Generación 300: Mejor distancia = 1696.45 km
# Generación 350: Mejor distancia = 1696.45 km
# Generación 400: Mejor distancia = 1696.45 km
# Generación 450: Mejor distancia = 1696.45 km
# Generación 500: Mejor distancia = 1696.45 km
# Iteración 10: Mejor costo hasta ahora = 361.48 km
# Iteración 20: Mejor costo hasta ahora = 337.66 km
# Iteración 30: Mejor costo hasta ahora = 337.66 km
# Iteración 40: Mejor costo hasta ahora = 327.77 km
# Iteración 50: Mejor costo hasta ahora = 325.69 km
# Iteración 60: Mejor costo hasta ahora = 325.69 km
# Iteración 70: Mejor costo hasta ahora = 325.69 km
# Iteración 80: Mejor costo hasta ahora = 325.69 km
# Iteración 90: Mejor costo hasta ahora = 325.69 km
# Iteración 100: Mejor costo hasta ahora = 325.69 km
# Resultados guardados en: resultados/6_200
#
#
# Archivo de inclusión generado: resultados/6_200/gams_6_200.inc
# Procesando archivo: redes/6_40.csv
# Generación 50: Mejor distancia = 276.59 km
# Generación 100: Mejor distancia = 200.67 km
# Generación 150: Mejor distancia = 181.12 km
# Generación 200: Mejor distancia = 179.17 km
# Generación 250: Mejor distancia = 173.59 km
# Generación 300: Mejor distancia = 172.72 km
# Generación 350: Mejor distancia = 172.72 km
# Generación 400: Mejor distancia = 172.72 km
# Generación 450: Mejor distancia = 172.35 km
# Generación 500: Mejor distancia = 172.35 km
# Iteración 10: Mejor costo hasta ahora = 144.31 km
# Iteración 20: Mejor costo hasta ahora = 143.83 km
# Iteración 30: Mejor costo hasta ahora = 143.72 km
# Iteración 40: Mejor costo hasta ahora = 142.60 km
# Iteración 50: Mejor costo hasta ahora = 142.60 km
# Iteración 60: Mejor costo hasta ahora = 142.60 km
# Iteración 70: Mejor costo hasta ahora = 142.60 km
# Iteración 80: Mejor costo hasta ahora = 142.60 km
# Iteración 90: Mejor costo hasta ahora = 142.60 km
# Iteración 100: Mejor costo hasta ahora = 142.60 km
# Resultados guardados en: resultados/6_40
#
#
# Archivo de inclusión generado: resultados/6_40/gams_6_40.inc
# Procesando archivo: redes/7_100.csv
# Generación 50: Mejor distancia = 846.65 km
# Generación 100: Mejor distancia = 821.85 km
# Generación 150: Mejor distancia = 821.85 km
# Generación 200: Mejor distancia = 821.85 km
# Generación 250: Mejor distancia = 821.85 km
# Generación 300: Mejor distancia = 821.85 km
# Generación 350: Mejor distancia = 815.54 km
# Generación 400: Mejor distancia = 815.54 km
# Generación 450: Mejor distancia = 815.54 km
# Generación 500: Mejor distancia = 814.68 km
# Iteración 10: Mejor costo hasta ahora = 222.90 km
# Iteración 20: Mejor costo hasta ahora = 222.90 km
# Iteración 30: Mejor costo hasta ahora = 216.31 km
# Iteración 40: Mejor costo hasta ahora = 216.31 km
# Iteración 50: Mejor costo hasta ahora = 216.31 km
# Iteración 60: Mejor costo hasta ahora = 216.31 km
# Iteración 70: Mejor costo hasta ahora = 216.31 km
# Iteración 80: Mejor costo hasta ahora = 216.31 km
# Iteración 90: Mejor costo hasta ahora = 216.31 km
# Iteración 100: Mejor costo hasta ahora = 216.31 km
# Resultados guardados en: resultados/7_100
#
#
# Archivo de inclusión generado: resultados/7_100/gams_7_100.inc
# Procesando archivo: redes/7_150.csv
# Generación 50: Mejor distancia = 1298.97 km
# Generación 100: Mejor distancia = 1268.41 km
# Generación 150: Mejor distancia = 1254.92 km
# Generación 200: Mejor distancia = 1254.92 km
# Generación 250: Mejor distancia = 1254.28 km
# Generación 300: Mejor distancia = 1251.85 km
# Generación 350: Mejor distancia = 1251.85 km
# Generación 400: Mejor distancia = 1251.85 km
# Generación 450: Mejor distancia = 1251.85 km
# Generación 500: Mejor distancia = 1251.85 km
# Iteración 10: Mejor costo hasta ahora = 296.46 km
# Iteración 20: Mejor costo hasta ahora = 280.06 km
# Iteración 30: Mejor costo hasta ahora = 280.06 km
# Iteración 40: Mejor costo hasta ahora = 279.92 km
# Iteración 50: Mejor costo hasta ahora = 279.92 km
# Iteración 60: Mejor costo hasta ahora = 279.92 km
# Iteración 70: Mejor costo hasta ahora = 279.92 km
# Iteración 80: Mejor costo hasta ahora = 279.92 km
# Iteración 90: Mejor costo hasta ahora = 277.69 km
# Iteración 100: Mejor costo hasta ahora = 277.69 km
# Resultados guardados en: resultados/7_150
#
#
# Archivo de inclusión generado: resultados/7_150/gams_7_150.inc
# Procesando archivo: redes/7_200.csv
# Generación 50: Mejor distancia = 1868.28 km
# Generación 100: Mejor distancia = 1767.76 km
# Generación 150: Mejor distancia = 1767.76 km
# Generación 200: Mejor distancia = 1757.06 km
# Generación 250: Mejor distancia = 1757.06 km
# Generación 300: Mejor distancia = 1757.06 km
# Generación 350: Mejor distancia = 1757.06 km
# Generación 400: Mejor distancia = 1757.06 km
# Generación 450: Mejor distancia = 1731.79 km
# Generación 500: Mejor distancia = 1731.79 km
# Iteración 10: Mejor costo hasta ahora = 316.96 km
# Iteración 20: Mejor costo hasta ahora = 302.45 km
# Iteración 30: Mejor costo hasta ahora = 292.06 km
# Iteración 40: Mejor costo hasta ahora = 292.06 km
# Iteración 50: Mejor costo hasta ahora = 292.06 km
# Iteración 60: Mejor costo hasta ahora = 292.06 km
# Iteración 70: Mejor costo hasta ahora = 292.06 km
# Iteración 80: Mejor costo hasta ahora = 292.06 km
# Iteración 90: Mejor costo hasta ahora = 292.06 km
# Iteración 100: Mejor costo hasta ahora = 292.06 km
# Resultados guardados en: resultados/7_200
#
#
# Archivo de inclusión generado: resultados/7_200/gams_7_200.inc
# Procesando archivo: redes/7_40.csv
# Generación 50: Mejor distancia = 284.54 km
# Generación 100: Mejor distancia = 267.38 km
# Generación 150: Mejor distancia = 252.30 km
# Generación 200: Mejor distancia = 224.10 km
# Generación 250: Mejor distancia = 190.93 km
# Generación 300: Mejor distancia = 186.30 km
# Generación 350: Mejor distancia = 182.77 km
# Generación 400: Mejor distancia = 182.01 km
# Generación 450: Mejor distancia = 179.09 km
# Generación 500: Mejor distancia = 179.05 km
# Iteración 10: Mejor costo hasta ahora = 144.48 km
# Iteración 20: Mejor costo hasta ahora = 142.72 km
# Iteración 30: Mejor costo hasta ahora = 139.29 km
# Iteración 40: Mejor costo hasta ahora = 139.29 km
# Iteración 50: Mejor costo hasta ahora = 139.29 km
# Iteración 60: Mejor costo hasta ahora = 139.29 km
# Iteración 70: Mejor costo hasta ahora = 139.29 km
# Iteración 80: Mejor costo hasta ahora = 139.29 km
# Iteración 90: Mejor costo hasta ahora = 139.29 km
# Iteración 100: Mejor costo hasta ahora = 139.29 km
# Resultados guardados en: resultados/7_40
#
#
# Archivo de inclusión generado: resultados/7_40/gams_7_40.inc
# Procesando archivo: redes/8_100.csv
# Generación 50: Mejor distancia = 800.68 km
# Generación 100: Mejor distancia = 787.65 km
# Generación 150: Mejor distancia = 746.91 km
# Generación 200: Mejor distancia = 746.91 km
# Generación 250: Mejor distancia = 746.91 km
# Generación 300: Mejor distancia = 745.12 km
# Generación 350: Mejor distancia = 742.77 km
# Generación 400: Mejor distancia = 742.77 km
# Generación 450: Mejor distancia = 742.77 km
# Generación 500: Mejor distancia = 742.77 km
# Iteración 10: Mejor costo hasta ahora = 196.93 km
# Iteración 20: Mejor costo hasta ahora = 184.93 km
# Iteración 30: Mejor costo hasta ahora = 184.93 km
# Iteración 40: Mejor costo hasta ahora = 184.93 km
# Iteración 50: Mejor costo hasta ahora = 184.93 km
# Iteración 60: Mejor costo hasta ahora = 184.93 km
# Iteración 70: Mejor costo hasta ahora = 183.67 km
# Iteración 80: Mejor costo hasta ahora = 183.67 km
# Iteración 90: Mejor costo hasta ahora = 182.16 km
# Iteración 100: Mejor costo hasta ahora = 181.27 km
# Resultados guardados en: resultados/8_100
#
#
# Archivo de inclusión generado: resultados/8_100/gams_8_100.inc
# Procesando archivo: redes/8_150.csv
# Generación 50: Mejor distancia = 1274.52 km
# Generación 100: Mejor distancia = 1246.52 km
# Generación 150: Mejor distancia = 1227.13 km
# Generación 200: Mejor distancia = 1227.13 km
# Generación 250: Mejor distancia = 1227.13 km
# Generación 300: Mejor distancia = 1227.13 km
# Generación 350: Mejor distancia = 1227.13 km
# Generación 400: Mejor distancia = 1227.13 km
# Generación 450: Mejor distancia = 1227.13 km
# Generación 500: Mejor distancia = 1220.49 km
# Iteración 10: Mejor costo hasta ahora = 307.84 km
# Iteración 20: Mejor costo hasta ahora = 292.55 km
# Iteración 30: Mejor costo hasta ahora = 289.96 km
# Iteración 40: Mejor costo hasta ahora = 289.96 km
# Iteración 50: Mejor costo hasta ahora = 284.23 km
# Iteración 60: Mejor costo hasta ahora = 284.23 km
# Iteración 70: Mejor costo hasta ahora = 284.23 km
# Iteración 80: Mejor costo hasta ahora = 284.23 km
# Iteración 90: Mejor costo hasta ahora = 284.23 km
# Iteración 100: Mejor costo hasta ahora = 284.23 km
# Resultados guardados en: resultados/8_150
#
#
# Archivo de inclusión generado: resultados/8_150/gams_8_150.inc
# Procesando archivo: redes/8_200.csv
# Generación 50: Mejor distancia = 1833.05 km
# Generación 100: Mejor distancia = 1800.67 km
# Generación 150: Mejor distancia = 1800.67 km
# Generación 200: Mejor distancia = 1797.57 km
# Generación 250: Mejor distancia = 1792.36 km
# Generación 300: Mejor distancia = 1792.36 km
# Generación 350: Mejor distancia = 1792.36 km
# Generación 400: Mejor distancia = 1790.62 km
# Generación 450: Mejor distancia = 1772.16 km
# Generación 500: Mejor distancia = 1772.16 km
# Iteración 10: Mejor costo hasta ahora = 348.88 km
# Iteración 20: Mejor costo hasta ahora = 333.84 km
# Iteración 30: Mejor costo hasta ahora = 333.84 km
# Iteración 40: Mejor costo hasta ahora = 333.84 km
# Iteración 50: Mejor costo hasta ahora = 333.84 km
# Iteración 60: Mejor costo hasta ahora = 330.74 km
# Iteración 70: Mejor costo hasta ahora = 330.74 km
# Iteración 80: Mejor costo hasta ahora = 330.74 km
# Iteración 90: Mejor costo hasta ahora = 330.74 km
# Iteración 100: Mejor costo hasta ahora = 330.74 km
# Resultados guardados en: resultados/8_200
#
#
# Archivo de inclusión generado: resultados/8_200/gams_8_200.inc
# Procesando archivo: redes/8_40.csv
# Generación 50: Mejor distancia = 267.70 km
# Generación 100: Mejor distancia = 214.52 km
# Generación 150: Mejor distancia = 180.73 km
# Generación 200: Mejor distancia = 172.57 km
# Generación 250: Mejor distancia = 166.81 km
# Generación 300: Mejor distancia = 164.59 km
# Generación 350: Mejor distancia = 161.98 km
# Generación 400: Mejor distancia = 161.98 km
# Generación 450: Mejor distancia = 161.98 km
# Generación 500: Mejor distancia = 161.98 km
# Iteración 10: Mejor costo hasta ahora = 147.85 km
# Iteración 20: Mejor costo hasta ahora = 145.49 km
# Iteración 30: Mejor costo hasta ahora = 145.49 km
# Iteración 40: Mejor costo hasta ahora = 144.88 km
# Iteración 50: Mejor costo hasta ahora = 144.88 km
# Iteración 60: Mejor costo hasta ahora = 144.88 km
# Iteración 70: Mejor costo hasta ahora = 144.88 km
# Iteración 80: Mejor costo hasta ahora = 144.41 km
# Iteración 90: Mejor costo hasta ahora = 144.41 km
# Iteración 100: Mejor costo hasta ahora = 144.41 km
# Resultados guardados en: resultados/8_40
#
#
# Archivo de inclusión generado: resultados/8_40/gams_8_40.inc
# Procesando archivo: redes/9_100.csv
# Generación 50: Mejor distancia = 789.47 km
# Generación 100: Mejor distancia = 731.18 km
# Generación 150: Mejor distancia = 731.18 km
# Generación 200: Mejor distancia = 731.18 km
# Generación 250: Mejor distancia = 731.18 km
# Generación 300: Mejor distancia = 731.18 km
# Generación 350: Mejor distancia = 731.18 km
# Generación 400: Mejor distancia = 731.18 km
# Generación 450: Mejor distancia = 731.18 km
# Generación 500: Mejor distancia = 731.18 km
# Iteración 10: Mejor costo hasta ahora = 205.56 km
# Iteración 20: Mejor costo hasta ahora = 205.56 km
# Iteración 30: Mejor costo hasta ahora = 201.26 km
# Iteración 40: Mejor costo hasta ahora = 198.20 km
# Iteración 50: Mejor costo hasta ahora = 198.20 km
# Iteración 60: Mejor costo hasta ahora = 198.20 km
# Iteración 70: Mejor costo hasta ahora = 198.20 km
# Iteración 80: Mejor costo hasta ahora = 196.72 km
# Iteración 90: Mejor costo hasta ahora = 196.72 km
# Iteración 100: Mejor costo hasta ahora = 196.72 km
# Resultados guardados en: resultados/9_100
#
#
# Archivo de inclusión generado: resultados/9_100/gams_9_100.inc
# Procesando archivo: redes/9_150.csv
# Generación 50: Mejor distancia = 1292.40 km
# Generación 100: Mejor distancia = 1290.35 km
# Generación 150: Mejor distancia = 1242.09 km
# Generación 200: Mejor distancia = 1242.09 km
# Generación 250: Mejor distancia = 1242.09 km
# Generación 300: Mejor distancia = 1242.09 km
# Generación 350: Mejor distancia = 1242.09 km
# Generación 400: Mejor distancia = 1242.09 km
# Generación 450: Mejor distancia = 1242.09 km
# Generación 500: Mejor distancia = 1204.17 km
# Iteración 10: Mejor costo hasta ahora = 300.52 km
# Iteración 20: Mejor costo hasta ahora = 281.28 km
# Iteración 30: Mejor costo hasta ahora = 281.28 km
# Iteración 40: Mejor costo hasta ahora = 281.28 km
# Iteración 50: Mejor costo hasta ahora = 281.28 km
# Iteración 60: Mejor costo hasta ahora = 281.28 km
# Iteración 70: Mejor costo hasta ahora = 281.28 km
# Iteración 80: Mejor costo hasta ahora = 281.28 km
# Iteración 90: Mejor costo hasta ahora = 281.28 km
# Iteración 100: Mejor costo hasta ahora = 281.28 km
# Resultados guardados en: resultados/9_150
#
#
# Archivo de inclusión generado: resultados/9_150/gams_9_150.inc
# Procesando archivo: redes/9_200.csv
# Generación 50: Mejor distancia = 1780.65 km
# Generación 100: Mejor distancia = 1780.65 km
# Generación 150: Mejor distancia = 1766.86 km
# Generación 200: Mejor distancia = 1750.62 km
# Generación 250: Mejor distancia = 1737.66 km
# Generación 300: Mejor distancia = 1737.66 km
# Generación 350: Mejor distancia = 1737.66 km
# Generación 400: Mejor distancia = 1720.06 km
# Generación 450: Mejor distancia = 1706.52 km
# Generación 500: Mejor distancia = 1706.52 km
# Iteración 10: Mejor costo hasta ahora = 315.31 km
# Iteración 20: Mejor costo hasta ahora = 300.69 km
# Iteración 30: Mejor costo hasta ahora = 300.69 km
# Iteración 40: Mejor costo hasta ahora = 295.24 km
# Iteración 50: Mejor costo hasta ahora = 295.24 km
# Iteración 60: Mejor costo hasta ahora = 295.24 km
# Iteración 70: Mejor costo hasta ahora = 295.24 km
# Iteración 80: Mejor costo hasta ahora = 295.24 km
# Iteración 90: Mejor costo hasta ahora = 295.24 km
# Iteración 100: Mejor costo hasta ahora = 295.24 km
# Resultados guardados en: resultados/9_200
#
#
# Archivo de inclusión generado: resultados/9_200/gams_9_200.inc
# Procesando archivo: redes/9_40.csv
# Generación 50: Mejor distancia = 231.63 km
# Generación 100: Mejor distancia = 168.18 km
# Generación 150: Mejor distancia = 140.71 km
# Generación 200: Mejor distancia = 139.26 km
# Generación 250: Mejor distancia = 138.82 km
# Generación 300: Mejor distancia = 137.32 km
# Generación 350: Mejor distancia = 134.95 km
# Generación 400: Mejor distancia = 130.66 km
# Generación 450: Mejor distancia = 130.66 km
# Generación 500: Mejor distancia = 130.66 km
# Iteración 10: Mejor costo hasta ahora = 109.41 km
# Iteración 20: Mejor costo hasta ahora = 108.78 km
# Iteración 30: Mejor costo hasta ahora = 108.18 km
# Iteración 40: Mejor costo hasta ahora = 108.18 km
# Iteración 50: Mejor costo hasta ahora = 108.18 km
# Iteración 60: Mejor costo hasta ahora = 108.18 km
# Iteración 70: Mejor costo hasta ahora = 108.18 km
# Iteración 80: Mejor costo hasta ahora = 108.18 km
# Iteración 90: Mejor costo hasta ahora = 108.18 km
# Iteración 100: Mejor costo hasta ahora = 108.18 km
# Resultados guardados en: resultados/9_40
#
#
# Archivo de inclusión generado: resultados/9_40/gams_9_40.inc
# Procesando archivo: redes/10_100.csv
# Generación 50: Mejor distancia = 790.19 km
# Generación 100: Mejor distancia = 769.45 km
# Generación 150: Mejor distancia = 766.10 km
# Generación 200: Mejor distancia = 766.10 km
# Generación 250: Mejor distancia = 766.10 km
# Generación 300: Mejor distancia = 766.10 km
# Generación 350: Mejor distancia = 766.10 km
# Generación 400: Mejor distancia = 762.59 km
# Generación 450: Mejor distancia = 761.49 km
# Generación 500: Mejor distancia = 761.49 km
# Iteración 10: Mejor costo hasta ahora = 219.72 km
# Iteración 20: Mejor costo hasta ahora = 219.72 km
# Iteración 30: Mejor costo hasta ahora = 219.72 km
# Iteración 40: Mejor costo hasta ahora = 218.30 km
# Iteración 50: Mejor costo hasta ahora = 218.30 km
# Iteración 60: Mejor costo hasta ahora = 218.30 km
# Iteración 70: Mejor costo hasta ahora = 218.30 km
# Iteración 80: Mejor costo hasta ahora = 215.35 km
# Iteración 90: Mejor costo hasta ahora = 215.35 km
# Iteración 100: Mejor costo hasta ahora = 215.35 km
# Resultados guardados en: resultados/10_100
#
#
# Archivo de inclusión generado: resultados/10_100/gams_10_100.inc
# Procesando archivo: redes/10_150.csv
# Generación 50: Mejor distancia = 1288.76 km
# Generación 100: Mejor distancia = 1281.49 km
# Generación 150: Mejor distancia = 1263.26 km
# Generación 200: Mejor distancia = 1261.41 km
# Generación 250: Mejor distancia = 1261.41 km
# Generación 300: Mejor distancia = 1261.41 km
# Generación 350: Mejor distancia = 1247.80 km
# Generación 400: Mejor distancia = 1247.80 km
# Generación 450: Mejor distancia = 1247.80 km
# Generación 500: Mejor distancia = 1240.98 km
# Iteración 10: Mejor costo hasta ahora = 308.20 km
# Iteración 20: Mejor costo hasta ahora = 298.02 km
# Iteración 30: Mejor costo hasta ahora = 290.17 km
# Iteración 40: Mejor costo hasta ahora = 288.34 km
# Iteración 50: Mejor costo hasta ahora = 280.38 km
# Iteración 60: Mejor costo hasta ahora = 280.38 km
# Iteración 70: Mejor costo hasta ahora = 280.38 km
# Iteración 80: Mejor costo hasta ahora = 280.38 km
# Iteración 90: Mejor costo hasta ahora = 280.38 km
# Iteración 100: Mejor costo hasta ahora = 280.38 km
# Resultados guardados en: resultados/10_150
#
#
# Archivo de inclusión generado: resultados/10_150/gams_10_150.inc
# Procesando archivo: redes/10_200.csv
# Generación 50: Mejor distancia = 1858.11 km
# Generación 100: Mejor distancia = 1783.91 km
# Generación 150: Mejor distancia = 1755.19 km
# Generación 200: Mejor distancia = 1754.23 km
# Generación 250: Mejor distancia = 1745.47 km
# Generación 300: Mejor distancia = 1707.63 km
# Generación 350: Mejor distancia = 1707.63 km
# Generación 400: Mejor distancia = 1707.63 km
# Generación 450: Mejor distancia = 1707.63 km
# Generación 500: Mejor distancia = 1707.63 km
# Iteración 10: Mejor costo hasta ahora = 351.66 km
# Iteración 20: Mejor costo hasta ahora = 330.36 km
# Iteración 30: Mejor costo hasta ahora = 330.36 km
# Iteración 40: Mejor costo hasta ahora = 327.71 km
# Iteración 50: Mejor costo hasta ahora = 327.71 km
# Iteración 60: Mejor costo hasta ahora = 327.71 km
# Iteración 70: Mejor costo hasta ahora = 322.04 km
# Iteración 80: Mejor costo hasta ahora = 322.04 km
# Iteración 90: Mejor costo hasta ahora = 322.04 km
# Iteración 100: Mejor costo hasta ahora = 316.48 km
# Resultados guardados en: resultados/10_200
#
#
# Archivo de inclusión generado: resultados/10_200/gams_10_200.inc
# Procesando archivo: redes/10_40.csv
# Generación 50: Mejor distancia = 333.28 km
# Generación 100: Mejor distancia = 283.74 km
# Generación 150: Mejor distancia = 219.43 km
# Generación 200: Mejor distancia = 171.58 km
# Generación 250: Mejor distancia = 161.48 km
# Generación 300: Mejor distancia = 160.36 km
# Generación 350: Mejor distancia = 157.98 km
# Generación 400: Mejor distancia = 157.98 km
# Generación 450: Mejor distancia = 157.40 km
# Generación 500: Mejor distancia = 157.40 km
# Iteración 10: Mejor costo hasta ahora = 146.26 km
# Iteración 20: Mejor costo hasta ahora = 146.26 km
# Iteración 30: Mejor costo hasta ahora = 146.26 km
# Iteración 40: Mejor costo hasta ahora = 146.12 km
# Iteración 50: Mejor costo hasta ahora = 146.12 km
# Iteración 60: Mejor costo hasta ahora = 146.12 km
# Iteración 70: Mejor costo hasta ahora = 146.12 km
# Iteración 80: Mejor costo hasta ahora = 146.12 km
# Iteración 90: Mejor costo hasta ahora = 146.12 km
# Iteración 100: Mejor costo hasta ahora = 146.12 km
# Resultados guardados en: resultados/10_40
#
#
# Archivo de inclusión generado: resultados/10_40/gams_10_40.inc
